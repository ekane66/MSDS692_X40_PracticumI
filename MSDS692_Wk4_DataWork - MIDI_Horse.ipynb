# %% [markdown]
# **MIDI Data Focus**
#
# I will focus on preparing and preprocessing the MIDI data. I <br>
#
# Horse - Phish. This song is just beautiful to listen to, I'm interested to see what I find.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.svm import SVC
from sklearn.multiclass import OneVsRestClassifier, OneVsOneClassifier

import warnings
warnings.filterwarnings("ignore")

# %%
pip install mido
# Out:
# Requirement already satisfied: mido in c:\users\ebdai\anaconda3\lib\site-packages (1.3.2)
# Requirement already satisfied: packaging~=23.1 in c:\users\ebdai\anaconda3\lib\site-packages (from mido) (23.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import mido

# %%
# Step 2: Read MIDI files - Phish - Divided Sky
midi_file = r'C:\Users\ebdai\OneDrive\Regis\MSDS692_X40 Data Science Practivum I\MIDI Files\Horse.mid'
midi = mido.MidiFile(midi_file)

# %%
# Step 3: Extract MIDI events
relevant_events = []
for track in midi.tracks:
    for msg in track:
        if msg.type in ['note_on', 'note_off', 'pitchwheel', 'control_change']:
            relevant_events.append(msg)

# %%
for i, track in enumerate(midi.tracks):
    print(f"Track {i+1}: {track}")
# Out:
# Track 1: MidiTrack([
#   Message('control_change', channel=0, control=0, value=0, time=0),
#   Message('program_change', channel=0, program=25, time=0),
#   Message('control_change', channel=1, control=0, value=0, time=0),
#   Message('program_change', channel=1, program=25, time=0),
#   Message('control_change', channel=2, control=0, value=0, time=0),
#   Message('program_change', channel=2, program=53, time=0),
#   Message('control_change', channel=3, control=0, value=0, time=0),
#   Message('program_change', channel=3, program=53, time=0),
#   Message('control_change', channel=4, control=0, value=0, time=0),
#   Message('program_change', channel=4, program=53, time=0),
#   MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=96, notated_32nd_notes_per_beat=8, time=0),
#   MetaMessage('sequencer_specific', data=(0, 0, 65), time=0),
#   MetaMessage('set_tempo', tempo=500000, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_on', channel=0, note=57, velocity=100, time=96),
#   Message('note_off', channel=0, note=57, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_on', channel=1, note=45, velocity=100, time=384),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_off', channel=0, note=64, velocity=64, time=4),
#   Message('note_on', channel=1, note=45, velocity=100, time=124),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_on', channel=0, note=57, velocity=100, time=96),
#   Message('note_off', channel=0, note=57, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_on', channel=1, note=45, velocity=100, time=384),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_off', channel=0, note=64, velocity=64, time=260),
#   Message('note_off', channel=1, note=45, velocity=64, time=124),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=64),
#   Message('note_on', channel=0, note=57, velocity=100, time=32),
#   Message('note_off', channel=0, note=57, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=0, note=56, velocity=100, time=32),
#   Message('note_off', channel=0, note=56, velocity=64, time=64),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=1, note=52, velocity=100, time=32),
#   Message('note_off', channel=1, note=52, velocity=64, time=64),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=1, note=53, velocity=100, time=32),
#   Message('note_off', channel=1, note=53, velocity=64, time=64),
#   Message('note_on', channel=0, note=57, velocity=100, time=32),
#   Message('note_off', channel=0, note=57, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_off', channel=0, note=64, velocity=64, time=64),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_on', channel=0, note=57, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=128),
#   Message('note_on', channel=0, note=57, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=128),
#   Message('note_on', channel=0, note=57, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=128),
#   Message('note_on', channel=0, note=57, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_on', channel=0, note=57, velocity=100, time=128),
#   Message('note_on', channel=0, note=60, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_off', channel=0, note=57, velocity=64, time=160),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=32),
#   Message('note_on', channel=0, note=60, velocity=100, time=96),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_on', channel=0, note=65, velocity=100, time=32),
#   Message('note_off', channel=0, note=65, velocity=64, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_off', channel=0, note=64, velocity=64, time=64),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_on', channel=0, note=65, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_off', channel=0, note=65, velocity=64, time=0),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_on', channel=0, note=60, velocity=100, time=0),
#   Message('note_off', channel=0, note=64, velocity=64, time=128),
#   Message('note_off', channel=0, note=60, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=64),
#   Message('note_on', channel=0, note=59, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=128),
#   Message('note_off', channel=0, note=59, velocity=64, time=0),
#   Message('note_on', channel=0, note=57, velocity=100, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=0),
#   Message('note_off', channel=0, note=57, velocity=64, time=128),
#   Message('note_off', channel=0, note=60, velocity=64, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=64),
#   Message('note_off', channel=1, note=52, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_off', channel=0, note=64, velocity=64, time=128),
#   Message('note_on', channel=0, note=62, velocity=100, time=64),
#   Message('note_on', channel=0, note=58, velocity=100, time=0),
#   Message('note_on', channel=1, note=46, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=58, velocity=64, time=0),
#   Message('note_off', channel=1, note=46, velocity=64, time=0),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_on', channel=1, note=46, velocity=100, time=128),
#   Message('note_off', channel=1, note=46, velocity=64, time=64),
#   Message('note_on', channel=1, note=53, velocity=100, time=32),
#   Message('note_off', channel=1, note=53, velocity=64, time=64),
#   Message('note_on', channel=0, note=58, velocity=100, time=32),
#   Message('note_off', channel=0, note=58, velocity=64, time=64),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_on', channel=1, note=46, velocity=100, time=32),
#   Message('note_off', channel=1, note=46, velocity=64, time=64),
#   Message('note_on', channel=1, note=53, velocity=100, time=32),
#   Message('note_off', channel=1, note=53, velocity=64, time=64),
#   Message('note_on', channel=0, note=58, velocity=100, time=32),
#   Message('note_off', channel=0, note=58, velocity=64, time=64),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_on', channel=1, note=46, velocity=100, time=32),
#   Message('note_off', channel=1, note=46, velocity=64, time=128),
#   Message('note_on', channel=1, note=53, velocity=100, time=64),
#   Message('note_off', channel=1, note=53, velocity=64, time=128),
#   MetaMessage('time_signature', numerator=2, denominator=4, clocks_per_click=96, notated_32nd_notes_per_beat=8, time=64),
#   Message('note_on', channel=0, note=58, velocity=100, time=0),
#   Message('note_off', channel=0, note=58, velocity=64, time=128),
#   Message('note_on', channel=0, note=62, velocity=100, time=64),
#   Message('note_off', channel=0, note=62, velocity=64, time=384),
#   MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=96, notated_32nd_notes_per_beat=8, time=192),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_on', channel=0, note=57, velocity=100, time=96),
#   Message('note_off', channel=0, note=57, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_on', channel=1, note=45, velocity=100, time=384),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_off', channel=0, note=64, velocity=64, time=256),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_on', channel=0, note=57, velocity=100, time=96),
#   Message('note_off', channel=0, note=57, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_on', channel=1, note=45, velocity=100, time=384),
#   Message('note_off', channel=1, note=45, velocity=64, time=256),
#   Message('note_on', channel=1, note=45, velocity=100, time=128),
#   Message('note_off', channel=0, note=64, velocity=64, time=256),
#   Message('note_off', channel=1, note=45, velocity=64, time=128),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=64),
#   Message('note_on', channel=0, note=57, velocity=100, time=32),
#   Message('note_off', channel=0, note=57, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=0, note=56, velocity=100, time=32),
#   Message('note_off', channel=0, note=56, velocity=64, time=64),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=1, note=52, velocity=100, time=32),
#   Message('note_off', channel=1, note=52, velocity=64, time=64),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=1, note=53, velocity=100, time=32),
#   Message('note_off', channel=1, note=53, velocity=64, time=64),
#   Message('note_on', channel=0, note=57, velocity=100, time=32),
#   Message('note_off', channel=0, note=57, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_off', channel=0, note=64, velocity=64, time=64),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_on', channel=0, note=57, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=128),
#   Message('note_on', channel=0, note=57, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=128),
#   Message('note_on', channel=0, note=57, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=128),
#   Message('note_on', channel=0, note=57, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=57, velocity=64, time=0),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_on', channel=0, note=57, velocity=100, time=128),
#   Message('note_on', channel=0, note=60, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_off', channel=0, note=57, velocity=64, time=160),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=32),
#   Message('note_on', channel=0, note=60, velocity=100, time=96),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_on', channel=0, note=65, velocity=100, time=32),
#   Message('note_off', channel=0, note=65, velocity=64, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_off', channel=0, note=64, velocity=64, time=64),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_on', channel=0, note=65, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_off', channel=0, note=65, velocity=64, time=0),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_on', channel=0, note=60, velocity=100, time=0),
#   Message('note_off', channel=0, note=64, velocity=64, time=128),
#   Message('note_off', channel=0, note=60, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=64),
#   Message('note_on', channel=0, note=59, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=128),
#   Message('note_off', channel=0, note=59, velocity=64, time=0),
#   Message('note_on', channel=0, note=57, velocity=100, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=0),
#   Message('note_off', channel=0, note=57, velocity=64, time=128),
#   Message('note_off', channel=0, note=60, velocity=64, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=64),
#   Message('note_off', channel=1, note=52, velocity=64, time=64),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=32),
#   Message('note_off', channel=0, note=64, velocity=64, time=128),
#   Message('note_on', channel=0, note=62, velocity=100, time=64),
#   Message('note_on', channel=0, note=58, velocity=100, time=0),
#   Message('note_on', channel=1, note=46, velocity=100, time=0),
#   Message('note_on', channel=1, note=53, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=58, velocity=64, time=0),
#   Message('note_off', channel=1, note=46, velocity=64, time=0),
#   Message('note_off', channel=1, note=53, velocity=64, time=0),
#   Message('note_on', channel=1, note=46, velocity=100, time=128),
#   Message('note_off', channel=1, note=46, velocity=64, time=64),
#   Message('note_on', channel=1, note=53, velocity=100, time=32),
#   Message('note_off', channel=1, note=53, velocity=64, time=64),
#   Message('note_on', channel=0, note=58, velocity=100, time=32),
#   Message('note_off', channel=0, note=58, velocity=64, time=64),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_on', channel=1, note=46, velocity=100, time=32),
#   Message('note_off', channel=1, note=46, velocity=64, time=64),
#   Message('note_on', channel=1, note=53, velocity=100, time=32),
#   Message('note_off', channel=1, note=53, velocity=64, time=64),
#   Message('note_on', channel=0, note=58, velocity=100, time=32),
#   Message('note_off', channel=0, note=58, velocity=64, time=64),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_on', channel=1, note=45, velocity=100, time=32),
#   Message('note_off', channel=1, note=45, velocity=64, time=64),
#   Message('note_on', channel=1, note=53, velocity=100, time=32),
#   Message('note_off', channel=1, note=53, velocity=64, time=64),
#   Message('note_on', channel=0, note=58, velocity=100, time=32),
#   Message('note_off', channel=0, note=58, velocity=64, time=64),
#   Message('note_on', channel=0, note=59, velocity=100, time=32),
#   Message('note_off', channel=0, note=59, velocity=64, time=64),
#   Message('note_on', channel=1, note=43, velocity=100, time=32),
#   Message('note_off', channel=1, note=43, velocity=64, time=256),
#   Message('note_on', channel=0, note=62, velocity=100, time=128),
#   Message('note_on', channel=0, note=67, velocity=100, time=0),
#   Message('note_on', channel=1, note=47, velocity=100, time=0),
#   Message('note_on', channel=1, note=43, velocity=100, time=0),
#   Message('note_on', channel=1, note=50, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=256),
#   Message('note_off', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=1, note=47, velocity=64, time=0),
#   Message('note_off', channel=1, note=43, velocity=64, time=0),
#   Message('note_off', channel=1, note=50, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=128),
#   Message('note_on', channel=0, note=67, velocity=100, time=0),
#   Message('note_on', channel=1, note=43, velocity=100, time=0),
#   Message('note_on', channel=1, note=47, velocity=100, time=0),
#   Message('note_on', channel=1, note=50, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=192),
#   Message('note_off', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=1, note=43, velocity=64, time=0),
#   Message('note_off', channel=1, note=47, velocity=64, time=0),
#   Message('note_off', channel=1, note=50, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=96),
#   Message('note_on', channel=0, note=67, velocity=100, time=0),
#   Message('note_on', channel=1, note=43, velocity=100, time=0),
#   Message('note_on', channel=1, note=47, velocity=100, time=0),
#   Message('note_on', channel=1, note=50, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_off', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=1, note=43, velocity=64, time=0),
#   Message('note_off', channel=1, note=47, velocity=64, time=0),
#   Message('note_off', channel=1, note=50, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_on', channel=0, note=67, velocity=100, time=0),
#   Message('note_on', channel=1, note=43, velocity=100, time=0),
#   Message('note_on', channel=1, note=47, velocity=100, time=0),
#   Message('note_on', channel=1, note=50, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_off', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=1, note=43, velocity=64, time=0),
#   Message('note_off', channel=1, note=47, velocity=64, time=0),
#   Message('note_off', channel=1, note=50, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_on', channel=0, note=67, velocity=100, time=0),
#   Message('note_on', channel=1, note=43, velocity=100, time=0),
#   Message('note_on', channel=1, note=47, velocity=100, time=0),
#   Message('note_on', channel=1, note=50, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_off', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=1, note=43, velocity=64, time=0),
#   Message('note_off', channel=1, note=47, velocity=64, time=0),
#   Message('note_off', channel=1, note=50, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_on', channel=0, note=67, velocity=100, time=0),
#   Message('note_on', channel=1, note=43, velocity=100, time=0),
#   Message('note_on', channel=1, note=47, velocity=100, time=0),
#   Message('note_on', channel=1, note=50, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_off', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=1, note=43, velocity=64, time=0),
#   Message('note_off', channel=1, note=47, velocity=64, time=0),
#   Message('note_off', channel=1, note=50, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_on', channel=0, note=62, velocity=100, time=32),
#   Message('note_on', channel=0, note=67, velocity=100, time=0),
#   Message('note_on', channel=1, note=43, velocity=100, time=0),
#   Message('note_on', channel=1, note=47, velocity=100, time=0),
#   Message('note_on', channel=1, note=50, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_off', channel=0, note=62, velocity=64, time=64),
#   Message('note_off', channel=0, note=67, velocity=64, time=0),
#   Message('note_off', channel=1, note=43, velocity=64, time=0),
#   Message('note_off', channel=1, note=47, velocity=64, time=0),
#   Message('note_off', channel=1, note=50, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=256),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=128),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=256),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=128),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=192),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=96),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=128),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=128),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=256),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=128),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=256),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=128),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=192),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=96),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   MetaMessage('time_signature', numerator=2, denominator=4, clocks_per_click=96, notated_32nd_notes_per_beat=8, time=32),
#   Message('note_on', channel=0, note=60, velocity=100, time=0),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_on', channel=2, note=69, velocity=127, time=96),
#   Message('note_on', channel=3, note=69, velocity=127, time=0),
#   Message('note_on', channel=4, note=69, velocity=127, time=0),
#   Message('note_off', channel=2, note=69, velocity=127, time=64),
#   Message('note_off', channel=3, note=69, velocity=127, time=0),
#   Message('note_off', channel=4, note=69, velocity=127, time=0),
#   Message('note_on', channel=2, note=69, velocity=127, time=32),
#   Message('note_on', channel=3, note=69, velocity=127, time=0),
#   Message('note_on', channel=4, note=69, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_off', channel=2, note=69, velocity=127, time=0),
#   Message('note_off', channel=3, note=69, velocity=127, time=0),
#   Message('note_off', channel=4, note=69, velocity=127, time=0),
#   Message('note_on', channel=2, note=69, velocity=127, time=32),
#   Message('note_on', channel=3, note=69, velocity=127, time=0),
#   Message('note_on', channel=4, note=69, velocity=127, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=96),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=2, note=69, velocity=127, time=32),
#   Message('note_off', channel=3, note=69, velocity=127, time=0),
#   Message('note_off', channel=4, note=69, velocity=127, time=0),
#   Message('note_on', channel=2, note=69, velocity=127, time=64),
#   Message('note_on', channel=3, note=69, velocity=127, time=0),
#   Message('note_on', channel=4, note=69, velocity=127, time=0),
#   Message('note_off', channel=2, note=69, velocity=127, time=128),
#   Message('note_off', channel=3, note=69, velocity=127, time=0),
#   Message('note_off', channel=4, note=69, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=32),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=2, note=71, velocity=127, time=32),
#   Message('note_on', channel=3, note=71, velocity=127, time=0),
#   Message('note_on', channel=4, note=71, velocity=127, time=0),
#   Message('note_off', channel=2, note=71, velocity=127, time=64),
#   Message('note_off', channel=3, note=71, velocity=127, time=0),
#   Message('note_off', channel=4, note=71, velocity=127, time=0),
#   MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=96, notated_32nd_notes_per_beat=8, time=32),
#   Message('note_on', channel=0, note=60, velocity=100, time=0),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=2, note=69, velocity=127, time=0),
#   Message('note_on', channel=3, note=69, velocity=127, time=0),
#   Message('note_on', channel=4, note=69, velocity=127, time=0),
#   Message('note_off', channel=2, note=69, velocity=127, time=128),
#   Message('note_off', channel=3, note=69, velocity=127, time=0),
#   Message('note_off', channel=4, note=69, velocity=127, time=0),
#   Message('note_on', channel=2, note=67, velocity=127, time=64),
#   Message('note_on', channel=3, note=67, velocity=127, time=0),
#   Message('note_on', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=128),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_off', channel=2, note=67, velocity=127, time=0),
#   Message('note_off', channel=3, note=67, velocity=127, time=0),
#   Message('note_off', channel=4, note=67, velocity=127, time=0),
#   Message('note_on', channel=2, note=64, velocity=127, time=96),
#   Message('note_on', channel=3, note=64, velocity=127, time=0),
#   Message('note_on', channel=4, note=64, velocity=127, time=0),
#   Message('note_off', channel=2, note=64, velocity=127, time=128),
#   Message('note_off', channel=3, note=64, velocity=127, time=0),
#   Message('note_off', channel=4, note=64, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=32),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_on', channel=2, note=65, velocity=127, time=32),
#   Message('note_on', channel=3, note=65, velocity=127, time=0),
#   Message('note_on', channel=4, note=65, velocity=127, time=0),
#   Message('note_off', channel=2, note=65, velocity=127, time=64),
#   Message('note_off', channel=3, note=65, velocity=127, time=0),
#   Message('note_off', channel=4, note=65, velocity=127, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_on', channel=2, note=67, velocity=127, time=0),
#   Message('note_on', channel=3, note=67, velocity=127, time=0),
#   Message('note_on', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=2, note=67, velocity=127, time=128),
#   Message('note_off', channel=3, note=67, velocity=127, time=0),
#   Message('note_off', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_on', channel=2, note=69, velocity=127, time=0),
#   Message('note_on', channel=3, note=69, velocity=127, time=0),
#   Message('note_on', channel=4, note=69, velocity=127, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=96),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_off', channel=2, note=69, velocity=127, time=32),
#   Message('note_off', channel=3, note=69, velocity=127, time=0),
#   Message('note_off', channel=4, note=69, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=32),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_on', channel=2, note=67, velocity=127, time=0),
#   Message('note_on', channel=3, note=67, velocity=127, time=0),
#   Message('note_on', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_off', channel=2, note=67, velocity=127, time=0),
#   Message('note_off', channel=3, note=67, velocity=127, time=0),
#   Message('note_off', channel=4, note=67, velocity=127, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_on', channel=2, note=64, velocity=127, time=0),
#   Message('note_on', channel=3, note=64, velocity=127, time=0),
#   Message('note_on', channel=4, note=64, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_off', channel=2, note=64, velocity=127, time=0),
#   Message('note_off', channel=3, note=64, velocity=127, time=0),
#   Message('note_off', channel=4, note=64, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
# ...
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_on', channel=2, note=67, velocity=127, time=0),
#   Message('note_on', channel=3, note=67, velocity=127, time=0),
#   Message('note_on', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_off', channel=2, note=67, velocity=127, time=0),
#   Message('note_off', channel=3, note=67, velocity=127, time=0),
#   Message('note_off', channel=4, note=67, velocity=127, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_on', channel=2, note=71, velocity=127, time=0),
#   Message('note_on', channel=3, note=71, velocity=127, time=0),
#   Message('note_on', channel=4, note=71, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_off', channel=2, note=71, velocity=127, time=0),
#   Message('note_off', channel=3, note=71, velocity=127, time=0),
#   Message('note_off', channel=4, note=71, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_on', channel=2, note=69, velocity=127, time=0),
#   Message('note_on', channel=3, note=69, velocity=127, time=0),
#   Message('note_on', channel=4, note=69, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=256),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=128),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=256),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=128),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=192),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_off', channel=2, note=69, velocity=127, time=68),
#   Message('note_off', channel=3, note=69, velocity=127, time=0),
#   Message('note_off', channel=4, note=69, velocity=127, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=28),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=64),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=32),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=128),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=60, velocity=100, time=64),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=45, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=57, velocity=100, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=128),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=45, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=57, velocity=64, time=0),
#   Message('note_on', channel=0, note=63, velocity=100, time=64),
#   Message('note_on', channel=0, note=66, velocity=100, time=0),
#   Message('note_on', channel=1, note=54, velocity=100, time=0),
#   Message('note_on', channel=1, note=59, velocity=100, time=0),
#   Message('note_on', channel=2, note=71, velocity=127, time=96),
#   Message('note_on', channel=3, note=71, velocity=127, time=0),
#   Message('note_on', channel=4, note=71, velocity=127, time=0),
#   Message('note_off', channel=2, note=71, velocity=127, time=64),
#   Message('note_off', channel=3, note=71, velocity=127, time=0),
#   Message('note_off', channel=4, note=71, velocity=127, time=0),
#   Message('note_on', channel=2, note=71, velocity=127, time=32),
#   Message('note_on', channel=3, note=71, velocity=127, time=0),
#   Message('note_on', channel=4, note=71, velocity=127, time=0),
#   Message('note_off', channel=2, note=71, velocity=127, time=64),
#   Message('note_off', channel=3, note=71, velocity=127, time=0),
#   Message('note_off', channel=4, note=71, velocity=127, time=0),
#   Message('note_on', channel=2, note=72, velocity=127, time=32),
#   Message('note_on', channel=3, note=72, velocity=127, time=0),
#   Message('note_on', channel=4, note=72, velocity=127, time=0),
#   Message('note_off', channel=2, note=72, velocity=127, time=64),
#   Message('note_off', channel=3, note=72, velocity=127, time=0),
#   Message('note_off', channel=4, note=72, velocity=127, time=0),
#   Message('note_on', channel=2, note=71, velocity=127, time=32),
#   Message('note_on', channel=3, note=71, velocity=127, time=0),
#   Message('note_on', channel=4, note=71, velocity=127, time=0),
#   Message('note_off', channel=0, note=63, velocity=64, time=128),
#   Message('note_off', channel=0, note=66, velocity=64, time=0),
#   Message('note_off', channel=1, note=54, velocity=64, time=0),
#   Message('note_off', channel=1, note=59, velocity=64, time=0),
#   Message('note_off', channel=2, note=71, velocity=127, time=0),
#   Message('note_off', channel=3, note=71, velocity=127, time=0),
#   Message('note_off', channel=4, note=71, velocity=127, time=0),
#   Message('note_on', channel=2, note=69, velocity=127, time=64),
#   Message('note_on', channel=3, note=69, velocity=127, time=0),
#   Message('note_on', channel=4, note=69, velocity=127, time=0),
#   Message('note_off', channel=2, note=69, velocity=127, time=128),
#   Message('note_off', channel=3, note=69, velocity=127, time=0),
#   Message('note_off', channel=4, note=69, velocity=127, time=0),
#   Message('note_on', channel=0, note=64, velocity=100, time=64),
#   Message('note_on', channel=1, note=40, velocity=100, time=0),
#   Message('note_on', channel=1, note=47, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=59, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=2, note=67, velocity=127, time=0),
#   Message('note_on', channel=3, note=67, velocity=127, time=0),
#   Message('note_on', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=2, note=67, velocity=127, time=128),
#   Message('note_off', channel=3, note=67, velocity=127, time=0),
#   Message('note_off', channel=4, note=67, velocity=127, time=0),
#   Message('note_on', channel=2, note=69, velocity=127, time=64),
#   Message('note_on', channel=3, note=69, velocity=127, time=0),
#   Message('note_on', channel=4, note=69, velocity=127, time=0),
#   Message('note_off', channel=2, note=69, velocity=127, time=128),
#   Message('note_off', channel=3, note=69, velocity=127, time=0),
#   Message('note_off', channel=4, note=69, velocity=127, time=0),
#   Message('note_on', channel=2, note=67, velocity=127, time=64),
#   Message('note_on', channel=3, note=67, velocity=127, time=0),
#   Message('note_on', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=0, note=64, velocity=64, time=128),
#   Message('note_off', channel=1, note=40, velocity=64, time=0),
#   Message('note_off', channel=1, note=47, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=59, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=2, note=67, velocity=127, time=64),
#   Message('note_off', channel=3, note=67, velocity=127, time=0),
#   Message('note_off', channel=4, note=67, velocity=127, time=0),
#   Message('note_on', channel=2, note=66, velocity=127, time=96),
#   Message('note_on', channel=3, note=66, velocity=127, time=0),
#   Message('note_on', channel=4, note=66, velocity=127, time=0),
#   Message('note_off', channel=2, note=66, velocity=127, time=64),
#   Message('note_off', channel=3, note=66, velocity=127, time=0),
#   Message('note_off', channel=4, note=66, velocity=127, time=0),
#   MetaMessage('time_signature', numerator=2, denominator=4, clocks_per_click=96, notated_32nd_notes_per_beat=8, time=32),
#   Message('note_on', channel=0, note=60, velocity=100, time=0),
#   Message('note_on', channel=0, note=64, velocity=100, time=0),
#   Message('note_on', channel=1, note=48, velocity=100, time=0),
#   Message('note_on', channel=1, note=52, velocity=100, time=0),
#   Message('note_on', channel=1, note=55, velocity=100, time=0),
#   Message('note_on', channel=2, note=67, velocity=127, time=0),
#   Message('note_on', channel=3, note=67, velocity=127, time=0),
#   Message('note_on', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=2, note=67, velocity=127, time=128),
#   Message('note_off', channel=3, note=67, velocity=127, time=0),
#   Message('note_off', channel=4, note=67, velocity=127, time=0),
#   Message('note_on', channel=2, note=67, velocity=127, time=64),
#   Message('note_on', channel=3, note=67, velocity=127, time=0),
#   Message('note_on', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=2, note=67, velocity=127, time=64),
#   Message('note_off', channel=3, note=67, velocity=127, time=0),
#   Message('note_off', channel=4, note=67, velocity=127, time=0),
#   Message('note_on', channel=2, note=67, velocity=127, time=32),
#   Message('note_on', channel=3, note=67, velocity=127, time=0),
#   Message('note_on', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=2, note=67, velocity=127, time=192),
#   Message('note_off', channel=3, note=67, velocity=127, time=0),
#   Message('note_off', channel=4, note=67, velocity=127, time=0),
#   Message('note_off', channel=0, note=60, velocity=64, time=32),
#   Message('note_off', channel=0, note=64, velocity=64, time=0),
#   Message('note_off', channel=1, note=48, velocity=64, time=0),
#   Message('note_off', channel=1, note=52, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_on', channel=2, note=69, velocity=127, time=64),
#   Message('note_on', channel=3, note=69, velocity=127, time=0),
#   Message('note_on', channel=4, note=69, velocity=127, time=0),
#   Message('note_off', channel=2, note=69, velocity=127, time=128),
#   Message('note_off', channel=3, note=69, velocity=127, time=0),
#   Message('note_off', channel=4, note=69, velocity=127, time=0),
#   MetaMessage('time_signature', numerator=4, denominator=4, clocks_per_click=96, notated_32nd_notes_per_beat=8, time=64),
#   Message('note_on', channel=1, note=43, velocity=100, time=0),
#   Message('note_on', channel=2, note=67, velocity=127, time=0),
#   Message('note_on', channel=3, note=67, velocity=127, time=0),
#   Message('note_on', channel=4, note=67, velocity=127, time=0),
#   Message('note_on', channel=1, note=47, velocity=100, time=96),
#   Message('note_on', channel=1, note=50, velocity=100, time=96),
#   Message('note_on', channel=1, note=55, velocity=100, time=96),
#   Message('note_on', channel=1, note=59, velocity=100, time=96),
#   Message('note_on', channel=0, note=67, velocity=100, time=96),
#   Message('note_off', channel=0, note=67, velocity=64, time=1024),
#   Message('note_off', channel=1, note=43, velocity=64, time=0),
#   Message('note_off', channel=1, note=47, velocity=64, time=0),
#   Message('note_off', channel=1, note=50, velocity=64, time=0),
#   Message('note_off', channel=1, note=55, velocity=64, time=0),
#   Message('note_off', channel=1, note=59, velocity=64, time=0),
#   Message('note_off', channel=2, note=67, velocity=127, time=0),
#   Message('note_off', channel=3, note=67, velocity=127, time=0),
#   Message('note_off', channel=4, note=67, velocity=127, time=0),
#   MetaMessage('end_of_track', time=0)])

# %%
import pandas as pd

# Step 4: Extract MIDI events  
relevant_events = []
for track in midi.tracks:
    for msg in track:
        if msg.type in ['note_on', 'note_off', 'pitchwheel', 'control_change']:
            if msg.type == 'note_on' or msg.type == 'note_off':
                note = msg.note if hasattr(msg, 'note') else None  
                velocity = msg.velocity if hasattr(msg, 'velocity') else None  
                relevant_events.append({
                    'time': msg.time,
                    'type': msg.type,
                    'note': note,
                    'velocity': velocity  
                })
            elif msg.type == 'pitchwheel':
                relevant_events.append({
                    'time': msg.time,
                    'type': msg.type,
                    'pitch': msg.pitch if hasattr(msg, 'pitch') else None  
                })
            elif msg.type == 'control_change':
                relevant_events.append({
                    'time': msg.time,
                    'type': msg.type,
                    'control_number': msg.control if hasattr(msg, 'control') else None,
                    'control_value': msg.value if hasattr(msg, 'value') else None  
                })

# Convert the data to a pandas DataFrame  
df = pd.DataFrame(relevant_events)

# Perform analysis or further processing on the DataFrame  
# For example, you can group the data by note and calculate statistics:
note_stats = df.groupby('note').agg({'time': ['min', 'max'], 'velocity': 'mean'})

# Print the resulting DataFrame  
print(note_stats)
# Out:
#      time          velocity
#       min   max        mean
# note
# 40.0    0     0   82.000000
# 43.0    0   256   82.000000
# 45.0    0   384   82.000000
# 46.0    0   128   82.000000
# 47.0    0    96   82.000000
# 48.0    0     0   82.000000
# 50.0    0    96   82.000000
# 52.0    0    64   82.000000
# 53.0    0   128   82.000000
# 54.0    0     0   82.000000
# 55.0    0    96   82.000000
# 56.0    0    64   82.000000
# 57.0    0   160   82.000000
# 58.0    0   128   82.000000
# 59.0    0    96   82.000000
# 60.0    0   256   82.000000
# 62.0    0   384   84.647059
# 63.0   64   128   82.000000
# 64.0    0   260   91.000000
# 65.0    0    64   94.272727
# 66.0    0   192  113.153846
# 67.0    0  1024  116.322034
# 69.0    0   128  127.000000
# 71.0    0    96  127.000000
# 72.0    0    64  127.000000

# %% [markdown]
# Once you have the MIDI data in a structured format like a pandas DataFrame, you can perform various analyses and transformations on the data to gain insights or achieve specific goals. Here are a few examples of what you can do next:
#
# **Statistical Analysis:** You can calculate statistics on the MIDI data to gain insights into the musical patterns. For example, you can calculate the average velocity or duration of notes, identify the most frequently played notes, or analyze the distribution of note lengths.
#
# **Pattern Recognition:** By analyzing the sequence of MIDI events, you can identify recurring patterns or motifs in the music. This can be useful for music composition, arrangement, or understanding the structure of a piece.
#
# **Visualization:** Visualize the MIDI data in different ways to gain a better understanding. For example, you can create plots or graphs to visualize the distribution of note velocities, visualize the frequency of different note values, or create a piano roll representation of the MIDI data.
#
# **Music Generation:** Use the MIDI data as a basis for generating new musical compositions. You can apply machine learning techniques or algorithms to learn from the patterns in the MIDI data and generate new melodies or harmonies.
#
# **Feature Extraction:** Extract meaningful features from the MIDI data to use in other applications. For example, you can extract features like chord progressions, key changes, or rhythm patterns to analyze or classify music.
#
# These are just a few examples of what you can do with MIDI data.

# %% [markdown]
# ## Statistical Analysis

# %%
import pandas as pd  
import matplotlib.pyplot as plt

# Step 5:
# Statistical Analysis  
# Calculate the average velocity for all notes  
average_velocity = note_stats['velocity']['mean']
print("Average Velocity:\n", average_velocity)

# Identify the note with the highest maximum velocity  
max_velocity_note = note_stats['velocity']['mean'].idxmax()
max_velocity = note_stats.loc[max_velocity_note, 'velocity']['mean']
print("Note with Highest Maximum Velocity:", max_velocity_note)
print("Maximum Velocity:\n", max_velocity)

# Visualization  
# Plot the minimum, maximum, and mean velocity for each note  
note_stats.plot(y=('time', 'min'), label='Minimum Time')
note_stats.plot(y=('time', 'max'), label='Maximum Time')
note_stats.plot(y=('velocity', 'mean'), label='Mean Velocity')
plt.xlabel('Note')
plt.ylabel('Value')
plt.title('Time and Velocity Statistics by Note')
plt.legend()
plt.show()
# Out:
# Average Velocity:
#  note
# 40.0     82.000000
# 43.0     82.000000
# 45.0     82.000000
# 46.0     82.000000
# 47.0     82.000000
# 48.0     82.000000
# 50.0     82.000000
# 52.0     82.000000
# 53.0     82.000000
# 54.0     82.000000
# 55.0     82.000000
# 56.0     82.000000
# 57.0     82.000000
# 58.0     82.000000
# 59.0     82.000000
# 60.0     82.000000
# 62.0     84.647059
# 63.0     82.000000
# 64.0     91.000000
# 65.0     94.272727
# 66.0    113.153846
# 67.0    116.322034
# 69.0    127.000000
# 71.0    127.000000
# 72.0    127.000000
# Name: mean, dtype: float64
# Note with Highest Maximum Velocity: 69.0
# Maximum Velocity:
#  127.0

# %% [markdown]
# The provided data represents the average velocity of different musical notes. Each note is represented by its corresponding MIDI note number. The "Average Velocity" column shows that all notes have an average velocity of 100.0.
#
# The "Note with Highest Maximum Velocity" indicates that the note with the highest maximum velocity is 29.0. The "Maximum Velocity" value for this note is 127.0.
#
# In summary, the data suggests that all notes in the dataset have the same average velocity of 100.0, and the note with the highest maximum velocity is note 69.0, which also has a velocity of 100.0.

# %% [markdown]
# ## Pattern Recognition:
#
# **N-gram Analysis:** Divide the MIDI event sequence into n-grams (subsequences of length n) and analyze the frequency of occurrence of each n-gram. This can help identify recurring patterns of notes, chords, or rhythms.
#
# **Hidden Markov Models (HMMs):** Model the sequence of MIDI events as a hidden Markov model, where the hidden states represent the underlying patterns or motifs. Train the HMM using the MIDI data and then use it to predict the most likely sequence of hidden states, which correspond to the identified patterns.
#
# **Frequent Itemset Mining:** Apply frequent itemset mining techniques, such as the Apriori algorithm or FP-growth, to identify frequent combinations of MIDI events. This can reveal recurring patterns or motifs consisting of multiple events, such as chord progressions or melodic sequences.
#
# **Symbolic Music Similarity Measures:** Compute similarity measures, such as edit distance or cosine similarity, between subsequences of the MIDI event sequence. This can help identify similar patterns or motifs that occur at different positions or with slight variations.

# %%
# N-gram Analysis:
from collections import Counter

# Assuming you have the MIDI event sequence stored as a list called 'midi_events'
n = 3  # Length of n-gram

# Generate n-grams from the MIDI event sequence  
ngrams = [tuple(df[i:i+n]) for i in range(len(df)-n+1)]

# Count the frequency of each n-gram  
ngram_counts = Counter(ngrams)

# Print the most common n-grams  
most_common_ngrams = ngram_counts.most_common(10)
for ngram, count in most_common_ngrams:
    print(ngram, count)
# Out:
# ('time', 'type', 'control_number', 'control_value', 'note', 'velocity') 1495

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1497 entries, 0 to 1496
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   time            1497 non-null   int64
#  1   type            1497 non-null   object
#  2   control_number  5 non-null      float64
#  3   control_value   5 non-null      float64
#  4   note            1492 non-null   float64
#  5   velocity        1492 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 70.3+ KB

# %%
df.shape[0]
# Out:
# 1497

# %%
df1 = df

# %%
df1
# Out:
#       time            type  control_number  control_value  note  velocity
# 0        0  control_change             0.0            0.0   NaN       NaN
# 1        0  control_change             0.0            0.0   NaN       NaN
# 2        0  control_change             0.0            0.0   NaN       NaN
# 3        0  control_change             0.0            0.0   NaN       NaN
# 4        0  control_change             0.0            0.0   NaN       NaN
# ...    ...             ...             ...            ...   ...       ...
# 1492     0        note_off             NaN            NaN  55.0      64.0
# 1493     0        note_off             NaN            NaN  59.0      64.0
# 1494     0        note_off             NaN            NaN  67.0     127.0
# 1495     0        note_off             NaN            NaN  67.0     127.0
# 1496     0        note_off             NaN            NaN  67.0     127.0
#
# [1497 rows x 6 columns]

# %%
import matplotlib.pyplot as plt

type_counts = df1['type'].value_counts()
plt.bar(type_counts.index, type_counts.values)
plt.xlabel('Type')
plt.ylabel('Count')
plt.title('Type Counts')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.plot(df1['time'], df1['note'])
plt.xlabel('Time')
plt.ylabel('Note')
plt.title('Time vs. Note')
plt.show()

# %%
# Hidden Markov Models (HMMs):

# %%
pip install hmmlearn
# Out:
# Requirement already satisfied: hmmlearn in c:\users\ebdai\anaconda3\lib\site-packages (0.3.2)
# Requirement already satisfied: scikit-learn!=0.22.0,>=0.16 in c:\users\ebdai\anaconda3\lib\site-packages (from hmmlearn) (1.4.1.post1)
# Requirement already satisfied: numpy>=1.10 in c:\users\ebdai\anaconda3\lib\site-packages (from hmmlearn) (1.22.4)
# Requirement already satisfied: scipy>=0.19 in c:\users\ebdai\anaconda3\lib\site-packages (from hmmlearn) (1.7.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\ebdai\anaconda3\lib\site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (3.3.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ebdai\anaconda3\lib\site-packages (from scikit-learn!=0.22.0,>=0.16->hmmlearn) (1.3.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Convert 'note' column to nonnegative integers, handling NaN values  
df1['note'] = df1['note'].fillna(-1)  # Fill NaN values with -1 or any other suitable value  
df1['note'] = df1['note'].astype(int)
df1['note'] = df1['note'].clip(lower=0)  # Clip negative values to 0

# Reshape the 'note' column to have two dimensions  
note_sequence = df1['note'].values.reshape(-1, 1)

# %%
import pandas as pd  
import numpy as np  
from hmmlearn import hmm

# Convert 'note' column to nonnegative integers  
df1['note'] = df1['note'].astype(int)
df1['note'] = df1['note'].clip(lower=0)  # Clip negative values to 0

# Reshape the 'note' column to have two dimensions  
X = df1['note'].values.reshape(-1, 1)

# Define the number of states and iterations  
n_states = 10  
n_iter = 100

# Create an instance of the HMM model  
model = hmm.MultinomialHMM(n_components=n_states, n_iter=n_iter)

# Fit the HMM model on the reshaped data  
model.fit(X)
# Out:
# MultinomialHMM has undergone major changes. The previous version was implementing a CategoricalHMM (a special case of MultinomialHMM). This new implementation follows the standard definition for a Multinomial distribution (e.g. as in https://en.wikipedia.org/wiki/Multinomial_distribution). See these issues for details:
# https://github.com/hmmlearn/hmmlearn/issues/335
# https://github.com/hmmlearn/hmmlearn/issues/340
# MultinomialHMM(n_components=10, n_iter=100,
#                n_trials=array([ 0,  0,  0, ..., 67, 67, 67]),
#                random_state=RandomState(MT19937) at 0x25A51AC3E40)

# %% [markdown]
# The MultinominalHMM represents the initialization of a MultinomialHMM model with specific parameters:
#
# n_components=10: This parameter specifies the number of hidden states in the HMM model. In this case, the model will have 10 hidden states.
#
# n_iter=100: This parameter determines the maximum number of iterations for the model to converge during training. The model will iterate up to 100 times or until convergence is reached.
#
# n_trials: This parameter represents the number of observations or trials associated with each data point. It is an array that contains the number of trials for each data point. The values in the array indicate the number of times a particular observation (data point) was observed.
#
# random_state: This parameter sets the random seed for reproducibility. It ensures that the model's random number generation is consistent across different runs.

# %%
import seaborn as sns

state_transition_matrix = model.transmat_

plt.figure(figsize=(8, 6))
sns.heatmap(state_transition_matrix, cmap='Blues', annot=True, fmt=".2f")
plt.xlabel('To State')
plt.ylabel('From State')
plt.title('State Transition Matrix')
plt.show()

# %%
# Observation Emission Matrix: Get the observation emission matrix from the HMM model
import seaborn as sns

observation_emission_matrix = model.emissionprob_

plt.figure(figsize=(8, 6))
sns.heatmap(observation_emission_matrix, cmap='Purples', annot=True, fmt=".2f")
plt.xlabel('Observation')
plt.ylabel('State')
plt.title('Observation Emission Matrix')
plt.show()

# %%
pip install music21
# Out:
# Requirement already satisfied: music21 in c:\users\ebdai\anaconda3\lib\site-packages (8.3.0)
# Requirement already satisfied: more-itertools in c:\users\ebdai\anaconda3\lib\site-packages (from music21) (10.2.0)
# Requirement already satisfied: numpy in c:\users\ebdai\anaconda3\lib\site-packages (from music21) (1.22.4)
# Requirement already satisfied: chardet in c:\users\ebdai\anaconda3\lib\site-packages (from music21) (4.0.0)
# Requirement already satisfied: joblib in c:\users\ebdai\anaconda3\lib\site-packages (from music21) (1.3.2)
# Requirement already satisfied: matplotlib in c:\users\ebdai\anaconda3\lib\site-packages (from music21) (3.5.2)
# Requirement already satisfied: requests in c:\users\ebdai\anaconda3\lib\site-packages (from music21) (2.32.3)
# Requirement already satisfied: jsonpickle in c:\users\ebdai\anaconda3\lib\site-packages (from music21) (3.0.4)
# Requirement already satisfied: webcolors>=1.5 in c:\users\ebdai\anaconda3\lib\site-packages (from music21) (1.13)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ebdai\anaconda3\lib\site-packages (from matplotlib->music21) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ebdai\anaconda3\lib\site-packages (from matplotlib->music21) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\ebdai\anaconda3\lib\site-packages (from matplotlib->music21) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ebdai\anaconda3\lib\site-packages (from matplotlib->music21) (10.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ebdai\anaconda3\lib\site-packages (from matplotlib->music21) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ebdai\anaconda3\lib\site-packages (from matplotlib->music21) (1.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ebdai\anaconda3\lib\site-packages (from matplotlib->music21) (3.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ebdai\anaconda3\lib\site-packages (from requests->music21) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ebdai\anaconda3\lib\site-packages (from requests->music21) (2024.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ebdai\anaconda3\lib\site-packages (from requests->music21) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ebdai\anaconda3\lib\site-packages (from requests->music21) (1.26.11)
# Requirement already satisfied: six>=1.5 in c:\users\ebdai\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->music21) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import music21

# %%
# Load MIDI data into a music21 stream object  
midi_data = music21.converter.parse(r'C:\Users\ebdai\OneDrive\Regis\MSDS692_X40 Data Science Practivum I\MIDI Files\Horse.mid')

# %%
# Assuming you have two MIDI event sequences stored as lists called 'sequence1' and 'sequence2'
sequence1 = [...]  # Replace with your MIDI event sequence  
sequence2 = [...]  # Replace with your MIDI event sequence  
subsequence_length = 4  # Length of subsequences

# %%
import music21

# Assuming you have a MIDI event sequence called 'sequence1' representing note numbers  
sequence1 = [60, 62, 64, 67, 69]  # Replace with your MIDI note numbers

# Convert the MIDI note numbers into Note objects  
stream1 = music21.stream.Stream()
for note_number in sequence1:
    note = music21.note.Note()
    note.pitch.midi = note_number  
    stream1.append(note)

# Print the stream  
print(stream1)
# Out:
# <music21.stream.Stream 0x25a59655d90>

# %%
# Piano Roll Visualization
import music21

# Assuming you have a music21 stream called 'stream1'
# Convert the stream to a MIDI file  
midi_file = 'output_Horse.mid'
stream1.write('midi', fp=midi_file)
# Out:
# 'output_Horse.mid'

# %%
pip install pretty_midi
# Out:
# Requirement already satisfied: pretty_midi in c:\users\ebdai\anaconda3\lib\site-packages (0.2.10)
# Requirement already satisfied: numpy>=1.7.0 in c:\users\ebdai\anaconda3\lib\site-packages (from pretty_midi) (1.22.4)
# Requirement already satisfied: six in c:\users\ebdai\anaconda3\lib\site-packages (from pretty_midi) (1.16.0)
# Requirement already satisfied: mido>=1.1.16 in c:\users\ebdai\anaconda3\lib\site-packages (from pretty_midi) (1.3.2)
# Requirement already satisfied: packaging~=23.1 in c:\users\ebdai\anaconda3\lib\site-packages (from mido>=1.1.16->pretty_midi) (23.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pretty_midi

# Load the MIDI file  
midi_data = pretty_midi.PrettyMIDI(midi_file)

# Create a piano roll visualization  
piano_roll = midi_data.get_piano_roll()

# Display the piano roll  
# You can use matplotlib or other libraries to visualize the piano roll  
import matplotlib.pyplot as plt

plt.imshow(piano_roll)
plt.xlabel('Time')
plt.ylabel('MIDI Note Number')
plt.show()

# %%
import pretty_midi  
import matplotlib.pyplot as plt  
import numpy as np

# %%
# Load the MIDI file  
midi_data = pretty_midi.PrettyMIDI(r'C:\Users\ebdai\OneDrive\Regis\MSDS692_X40 Data Science Practivum I\MIDI Files\Horse.mid')

# %%
# Extract pitch and timing information from the MIDI data  
pitches = []
timings = []

for instrument in midi_data.instruments:
    for note in instrument.notes:
        pitches.append(note.pitch)
        timings.append(note.start)

# %%
# Convert timings to angles  
angles = np.array(timings) * 2 * np.pi

# %%
# Set up the plot  
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect('equal')
ax.axis('off')

# Plot the spirograph-like visualization  
ax.scatter(np.cos(angles), np.sin(angles), c=pitches, cmap='rainbow', s=10)

# Show the plot  
plt.show()

# %%
import pretty_midi  
import matplotlib.pyplot as plt  
import numpy as np

# Load the MIDI file  
midi_data = pretty_midi.PrettyMIDI(r'C:\Users\ebdai\OneDrive\Regis\MSDS692_X40 Data Science Practivum I\MIDI Files\Horse.mid')

# %%
# Extract pitch, timing, and amplitude information from the MIDI data  
pitches = []
timings = []
amplitudes = []

for instrument in midi_data.instruments:
    for note in instrument.notes:
        pitches.append(note.pitch)
        timings.append(note.start)
        amplitudes.append(note.velocity)

# Convert timings to angles  
angles = np.array(timings) * 2 * np.pi

# Convert amplitudes to a NumPy array  
amplitudes = np.array(amplitudes)

# Set up the plot  
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect('equal')
ax.axis('off')

# Plot the spirograph-like visualization with variations in amplitude  
ax.scatter(np.cos(angles), np.sin(angles), c=pitches, cmap='plasma', s=amplitudes*8.0)

# Show the plot  
plt.show()
